# %%
import aiohttp
import asyncio
from datetime import datetime, timezone, timedelta
import async_timeout
import pandas

ECOPWR_DAYAHEAD_URL_ACC = "https://acc.ameo.app/api/v2/characteristics/{CURVE}"
ECOPWR_DAYAHEAD_URL = "https://cloud.ameo.app/api/v2/characteristics/{CURVE}"
ECOPWR_HEADERS = {
    "Content-type": "application/json; charset=UTF-8",
    "authorization": "Bearer {TOKEN}",
}


class EcopowerApiClient:
    def __init__(
        self, session: aiohttp.ClientSession, token: str, curve_c, curve_i, test_api
    ) -> None:
        self._token = token
        self._session = session
        self._test_api = test_api
        self._url_c = ECOPWR_DAYAHEAD_URL.format(CURVE=curve_c)
        self._url_i = ECOPWR_DAYAHEAD_URL.format(CURVE=curve_i)
        if self._test_api:
            self._url_c = ECOPWR_DAYAHEAD_URL_ACC.format(CURVE=curve_c)
            self._url_i = ECOPWR_DAYAHEAD_URL_ACC.format(CURVE=curve_i)
        # _LOGGER.debug(f"urls: {self._url_c}, {self.url_i}")

    async def async_get_data(self, url) -> dict:
        async with async_timeout.timeout(8):
            headers = ECOPWR_HEADERS
            headers["authorization"] = f"Bearer {self._token}"
            response = await self._session.get(url, headers=headers)
            response.raise_for_status()
            data = await response.json()
            df = pandas.DataFrame.from_records(data["values"], index="date")
            # df.index = pandas.to_datetime(df.index).tz_convert(tz="Europe/Brussels") 
            # df["value"] = df["value"] * 10**-3  # MWh -> KWh
            # #df.round("H") df = df.drop_duplicates()
            # df = df.groupby(pandas.Grouper(freq='60Min')).mean()
            return df



ecopwr_token = ""
curve_c = 888
curve_i = 889
ecopower_session = aiohttp.ClientSession()
ecopower_client = EcopowerApiClient(
    ecopower_session, ecopwr_token, curve_c, curve_i, None
)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7fb729c91970>

# %%
test =await ecopower_client.async_get_data(ecopower_client._url_c)
test.index = test.index.tz_convert(tz="UTC").floor("H")
test = test.drop_duplicates(ignore_index=False)

# %%
path="/home/jan/code_projects/core/config/home-assistant_v2.db"
import pandas
import sqlite3

# Read sqlite query results into a pandas DataFrame
con = sqlite3.connect(path)

# %%
df=pandas.read_sql_query("select * FROM states where entity_id = 'sensor.ecopower_consumption_price_2';", con)
# df.drop_duplicates(subset=['last_updated','context_id'], keep='last')
df.tail(40)
# Out:
#     state_id                            entity_id    state attributes  \
# 0         10  sensor.ecopower_consumption_price_2  unknown       None
# 1         41  sensor.ecopower_consumption_price_2  unknown       None
# 2         76  sensor.ecopower_consumption_price_2  unknown       None
# 3        162  sensor.ecopower_consumption_price_2  unknown       None
# 4        195  sensor.ecopower_consumption_price_2  unknown       None
# 5        228  sensor.ecopower_consumption_price_2  unknown       None
# 6        261  sensor.ecopower_consumption_price_2  unknown       None
# 7        293  sensor.ecopower_consumption_price_2  unknown       None
# 8        328  sensor.ecopower_consumption_price_2  unknown       None
# 9        360  sensor.ecopower_consumption_price_2  unknown       None
# 10       500  sensor.ecopower_consumption_price_2  unknown       None
# 11       557  sensor.ecopower_consumption_price_2  unknown       None
# 12       589  sensor.ecopower_consumption_price_2  unknown       None
# 13      1067  sensor.ecopower_consumption_price_2  unknown       None
#
#    event_id last_changed                last_updated old_state_id  \
# 0      None         None  2022-09-16 23:07:10.844005         None
# 1      None         None  2022-09-16 23:10:14.558296         None
# 2      None         None  2022-09-16 23:20:40.158105         None
# 3      None         None  2022-09-17 22:17:49.946620         None
# 4      None         None  2022-09-17 22:23:46.501301         None
# 5      None         None  2022-09-17 22:28:30.068609         None
# 6      None         None  2022-09-17 22:38:26.726075         None
# 7      None         None  2022-09-17 22:45:23.451812         None
# 8      None         None  2022-09-17 22:53:05.761688         None
# 9      None         None  2022-09-17 22:55:54.039652         None
# 10     None         None  2022-09-17 23:01:22.978719         None
# 11     None         None  2022-09-17 23:05:46.291674         None
# 12     None         None  2022-09-17 23:09:07.678133         None
# 13     None         None  2022-09-17 23:35:21.618079         None
#
#     attributes_id                  context_id context_user_id  \
# 0               8  01GD48WN3WXT1MW8W96RFWF9VJ            None
# 1               8  01GD4928GYR9E5NE89Z0MJRGPF            None
# 2               8  01GD49NBEY1F3FJESDK3S5P8B6            None
# 3               8  01GD6RF0KTQSYM3HVJM05BZMR8            None
# 4               8  01GD6RSWT5HMR1MVAKY7Y76BZV            None
# 5               8  01GD6S2HQMZ6Z89V07JDZ1S1KP            None
# 6               8  01GD6SMRD6SJDRTS4CFK69K8C4            None
# 7               8  01GD6T1FBV8GAE0TYNFF3130ME            None
# 8               8  01GD6TFJV1WW3B1613ED26QHPE            None
# 9               8  01GD6TMQ5QXERJMXF554PVMEKR            None
# 10              8  01GD6TYRD2VDSJC9ZW9JM29BA1            None
# 11              8  01GD6V6SHKF6EFN9S5ZP6ASJCH            None
# 12              8  01GD6VCY6Y35AYE116Q028GYDP            None
# 13              8  01GD6WWZ8JQ26A1BHAR2GWCHRN            None
#
#    context_parent_id  origin_idx
# 0               None           0
# 1               None           0
# 2               None           0
# 3               None           0
# 4               None           0
# 5               None           0
# 6               None           0
# 7               None           0
# 8               None           0
# 9               None           0
# 10              None           0
# 11              None           0
# 12              None           0
# 13              None           0

# %%
df = pandas.read_sql_query("select * FROM statistics;", con)
# print(df.loc[7,'shared_attrs'])
df
# Out:
#     id                     created                       start      mean  \
# 0    1  2022-09-18 20:19:55.443729  2022-09-18 16:00:00.000000  0.335783
# 1    2  2022-09-18 20:19:55.446583  2022-09-18 17:00:00.000000  0.392058
# 2    3  2022-09-18 20:19:55.447278  2022-09-18 18:00:00.000000  0.439811
# 3    4  2022-09-18 20:19:55.447896  2022-09-18 19:00:00.000000  0.387383
# 4    5  2022-09-18 20:19:55.448432  2022-09-18 20:00:00.000000  0.345619
# 22  0.367938  0.367938       None  None  None            1
# 23  0.521638  0.521638       None  None  None            1
# 24  0.582514  0.582514       None  None  None            1
# 25  0.619211  0.619211       None  None  None            1
# 26  0.595891  0.595891       None  None  None            1
# 27  0.522438  0.522438       None  None  None            1
# 28  0.488179  0.488179       None  None  None            1
# 29  0.439429  0.439429       None  None  None            1
# 30  0.196610  0.196610       None  None  None            2
# 31  0.249700  0.249700       None  None  None            2
# 32  0.294750  0.294750       None  None  None            2
# 33  0.245290  0.245290       None  None  None            2
# 34  0.205890  0.205890       None  None  None            2
# 35  0.204700  0.204700       None  None  None            2
# 36  0.116860  0.116860       None  None  None            2
# 37  0.148640  0.148640       None  None  None            2
# 38  0.163990  0.163990       None  None  None            2
# 39  0.131070  0.131070       None  None  None            2
# 40  0.108870  0.108870       None  None  None            2
# 41  0.169510  0.169510       None  None  None            2
# 42  0.342570  0.342570       None  None  None            2
# 43  0.397410  0.397410       None  None  None            2
# 44  0.413080  0.413080       None  None  None            2
# 45  0.335780  0.335780       None  None  None            2
# 46  0.320300  0.320300       None  None  None            2
# 47  0.261300  0.261300       None  None  None            2
# 48  0.245090  0.245090       None  None  None            2
# 49  0.218110  0.218110       None  None  None            2
# 50  0.190800  0.190800       None  None  None            2
# 51  0.137160  0.137160       None  None  None            2
# 52  0.202700  0.202700       None  None  None            2
# 53  0.347700  0.347700       None  None  None            2
# 54  0.405130  0.405130       None  None  None            2
# 55  0.439750  0.439750       None  None  None            2
# 56  0.417750  0.417750       None  None  None            2
# 57  0.372700  0.372700       None  None  None            2
# 58  0.340380  0.340380       None  None  None            2
# 59  0.294390  0.294390       None  None  None            2

# %%
insert_df=test.drop(columns='valueStatus')
insert_df.index=insert_df.index.floor("H") 
insert_df= insert_df.reset_index().drop_duplicates(ignore_index=True)#.reset_index()
insert_df

# %%
import homeassistant.util.ulid as ulid_util
import homeassistant.util.dt as dt_util

df = pandas.read_sql_query("select * FROM states;", con)
offset= len(df) + 1

insert_df=test.drop(columns='valueStatus')
insert_df.index=insert_df.index.floor("H") 
insert_df = insert_df.reset_index().drop_duplicates(ignore_index=True)
insert_df['date'] = insert_df['date'].dt.tz_convert(tz=None)
insert_df=insert_df.rename(columns={'date':'last_updated','value':'state'})
insert_df['entity_id']='sensor.ecopower_consumption_price'
insert_df['attributes_id']=8
insert_df['context_id'] = insert_df['last_updated'].apply(lambda x: ulid_util.ulid(dt_util.utc_to_timestamp(x)))
insert_df['origin_idx'] = 0 
insert_df['state_id'] = insert_df.index +  offset
for col in df.columns:
    if col not in insert_df.columns:
        insert_df[col]=None

insert_df

# %%
insert_df.to_sql(
    'states',
    con,
    schema=None,
    if_exists="append",
    index=False,
    # dtype=None,
    # method=None, #change for perf
)

# %%
pandas.read_sql_query("select * FROM states where entity_id='sensor.ecopower_consumption_price';", con)
